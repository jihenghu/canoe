# %% [markdown]
# ##  Dry and Moist sumulations in Jovian EZ zone
#
# - Note: restart the jupyter kernel before rerunning, otherwise you will get a runtime error

# %%
#! /usr/bin/env python3
import numpy as np
import sys
import h5py

sys.path.append("../python")  # Adjust the path to build/python/
sys.path.append(".")

## load the necessary modules
from canoe import def_species, load_configure, index_map
from canoe.snap import def_thermo
from canoe.athena import Mesh, ParameterInput, Outputs, MeshBlock
from canoe.harp import radiation_band, radiation

# %%
# load the configuration file
pin = ParameterInput()
pin.load_from_file("juno_mwr.inp")
pin.set_boolean("job", "verbose", False)  

# register the speicies and thermodynamics
vapors = pin.get_string("species", "vapor").split(", ")
clouds = pin.get_string("species", "cloud").split(", ")
tracers = pin.get_string("species", "tracer").split(", ")

def_species(vapors=vapors, clouds=clouds, tracers=tracers)
def_thermo(pin)

# load bands and opacities
config = load_configure("juno_mwr.yaml")
# Out:
# Log, "2025-06-13 15:45:08",        canoe, 1., "Installing monitor canoe"
# Log, "2025-06-13 15:45:08",        canoe, 1.1., "Initialize IndexMap"
# Log, "2025-06-13 15:45:08",         snap, 3., "Installing monitor snap"
# Log, "2025-06-13 15:45:08",         snap, 3.1., "Initialize Thermodynamics"
# Log, "2025-06-13 15:45:08",         snap, 3.1.1., "Enrolling vapor functions"
# Log, "2025-06-13 15:45:08",         snap, 3.1.1.1., "Enrolling H2O vapor pressures"
# Log, "2025-06-13 15:45:08",         snap, 3.1.2.1., "Enrolling NH3 vapor pressures"

# %%
# set incident angles 
angle =[0.0, 15, 30.0, 45.]  # in degrees
angles = ' '.join([f"({x},)" for x in angle])
pin.set_string("radiation","outdir",angles)

print(pin.get_string("radiation","outdir"))
# Out:
# (0.0,) (15,) (30.0,) (45.0,)

# %%
# set the gravity 
pin.set_string("hydro", "grav_acc1", f"{-23.3}") # Equatorial zone
# pin.set_string("hydro", "grav_acc1", f"{-27.01}") # pole 

print("Gravity acceleration:", pin.get_string("hydro", "grav_acc1"))
# Out:
# Gravity acceleration: -23.3

# %%
# get index_map 
pindex = index_map.get_instance()
iNH3 = pindex.get_vapor_id("NH3")
iH2O = pindex.get_vapor_id("H2O")

print(f"iNH3 = {iNH3}, iH2O = {iH2O}")

P0 = pin.get_real("mesh", "ReferencePressure")
print(f"Reference Pressure: {P0} Pa")
# Out:
# iNH3 = 2, iH2O = 1
# Reference Pressure: 100000.0 Pa

# %%
# set mesh; we use the 1st column of the 1st meshblock of the Athena++ mesh

nx2 = 1  # air column number, single column in this case
pin.set_string("mesh", "nx2", f"{nx2}")

# init the Mesh
mesh = Mesh(pin) 
mesh.initialize(pin)

# get the first meshblock
mb = mesh.meshblock(0)
# Out:
# Log, "2025-06-13 15:45:08",         snap, 4.1., "Initialize Decomposition"
# Log, "2025-06-13 15:45:08",         snap, 5.1., "Initialize ImplicitSolver"
# Log, "2025-06-13 15:45:08", microphysics, 7., "Installing monitor microphysics"
# Log, "2025-06-13 15:45:08", microphysics, 7.1., "Initialize Microphysics"
# Log, "2025-06-13 15:45:08",         harp, 9., "Installing monitor harp"
# Log, "2025-06-13 15:45:08",         harp, 9.1., "Initialize Radiation"
# Log, "2025-06-13 15:45:08",         harp, 9.1.1., "Load Radiation bands from juno_mwr.yaml"
# Log, "2025-06-13 15:45:08",         harp, 9.1.1.1., "Initialize RadiationBand CH1"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.1.2., "Installing monitor opacity"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.1.2.1., "Create Absorber CIA"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.1.3.1., "Create Absorber NH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.1.4.1., "Create Absorber H2O"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.1.5.1., "Create Absorber Electron"
# Log, "2025-06-13 15:45:08",         harp, 9.1.1.6.1., "Initialize RTSolver Lambert"
# Log, "2025-06-13 15:45:08",         harp, 9.1.1.8., "Spectral range = 0.60 - 0.60"
# Log, "2025-06-13 15:45:08",         harp, 9.1.1.9., "Number of spectral bins = 1"
# Log, "2025-06-13 15:45:08",         harp, 9.1.2.1., "Initialize RadiationBand CH2"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.2.1.1., "Create Absorber CIA"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.2.2.1., "Create Absorber NH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.2.3.1., "Create Absorber H2O"
# Log, "2025-06-13 15:45:08",         harp, 9.1.2.4.1., "Initialize RTSolver Lambert"
# Log, "2025-06-13 15:45:08",         harp, 9.1.2.6., "Spectral range = 1.25 - 1.25"
# Log, "2025-06-13 15:45:08",         harp, 9.1.2.7., "Number of spectral bins = 1"
# Log, "2025-06-13 15:45:08",         harp, 9.1.3.1., "Initialize RadiationBand CH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.3.1.1., "Create Absorber CIA"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.3.2.1., "Create Absorber NH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.3.3.1., "Create Absorber H2O"
# Log, "2025-06-13 15:45:08",         harp, 9.1.3.4.1., "Initialize RTSolver Lambert"
# Log, "2025-06-13 15:45:08",         harp, 9.1.3.6., "Spectral range = 2.60 - 2.60"
# Log, "2025-06-13 15:45:08",         harp, 9.1.3.7., "Number of spectral bins = 1"
# Log, "2025-06-13 15:45:08",         harp, 9.1.4.1., "Initialize RadiationBand CH4"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.4.1.1., "Create Absorber CIA"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.4.2.1., "Create Absorber NH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.4.3.1., "Create Absorber H2O"
# Log, "2025-06-13 15:45:08",         harp, 9.1.4.4.1., "Initialize RTSolver Lambert"
# Log, "2025-06-13 15:45:08",         harp, 9.1.4.6., "Spectral range = 5.20 - 5.20"
# Log, "2025-06-13 15:45:08",         harp, 9.1.4.7., "Number of spectral bins = 1"
# Log, "2025-06-13 15:45:08",         harp, 9.1.5.1., "Initialize RadiationBand CH5"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.5.1.1., "Create Absorber CIA"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.5.2.1., "Create Absorber NH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.5.3.1., "Create Absorber H2O"
# Log, "2025-06-13 15:45:08",         harp, 9.1.5.4.1., "Initialize RTSolver Lambert"
# Log, "2025-06-13 15:45:08",         harp, 9.1.5.6., "Spectral range = 10.00 - 10.00"
# Log, "2025-06-13 15:45:08",         harp, 9.1.5.7., "Number of spectral bins = 1"
# Log, "2025-06-13 15:45:08",         harp, 9.1.6.1., "Initialize RadiationBand CH6"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.6.1.1., "Create Absorber CIA"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.6.2.1., "Create Absorber NH3"
# Log, "2025-06-13 15:45:08",      opacity, 9.1.6.3.1., "Create Absorber H2O"
# Log, "2025-06-13 15:45:08",         harp, 9.1.6.4.1., "Initialize RTSolver Lambert"
# Log, "2025-06-13 15:45:08",         harp, 9.1.6.6., "Spectral range = 22.00 - 22.00"
# Log, "2025-06-13 15:45:08",         harp, 9.1.6.7., "Number of spectral bins = 1"
# Log, "2025-06-13 15:45:08",       tracer, 11., "Installing monitor tracer"
# Log, "2025-06-13 15:45:08",       tracer, 11.1., "Initialize Tracer"
# Log, "2025-06-13 15:45:08",         snap, 12.1., "Create turbulenceModel"
# Log, "2025-06-13 15:45:08", single_column, 14., "Installing monitor single_column"
# Log, "2025-06-13 15:45:08", single_column, 14.1., "Initialize SingleColumn"
# Log, "2025-06-13 15:45:08",         main, 16., "Installing monitor main"
# Log, "2025-06-13 15:45:08",         main, 16.1., "ProblemGenerator: juno"
# Log, "2025-06-13 15:45:08",         main, 16.2., "request T = 169"
# Log, "2025-06-13 15:45:08",         main, 16.3., "request P = 100000"
# Log, "2025-06-13 15:45:08",         main, 16.4., "index of H2O = 1"
# Log, "2025-06-13 15:45:08",         main, 16.5., "index of NH3 = 2"
# Log, "2025-06-13 15:45:08",         main, 16.6., "Iteration # = 1"
# Log, "2025-06-13 15:45:08",         main, 16.7., "T = 183.815"
# Log, "2025-06-13 15:45:08",         main, 16.8., "Iteration # = 2"
# Log, "2025-06-13 15:45:08",         main, 16.9., "T = 182.354"
# Log, "2025-06-13 15:45:08",         main, 16.10., "Iteration # = 3"
# Log, "2025-06-13 15:45:08",         main, 16.11., "T = 181.039"
# Log, "2025-06-13 15:45:08",         main, 16.12., "Iteration # = 4"
# Log, "2025-06-13 15:45:08",         main, 16.13., "T = 179.854"
# Log, "2025-06-13 15:45:08",         main, 16.14., "Iteration # = 5"
# Log, "2025-06-13 15:45:08",         main, 16.15., "T = 178.787"
# Log, "2025-06-13 15:45:08",         main, 16.16., "Iteration # = 6"
# Log, "2025-06-13 15:45:08",         main, 16.17., "T = 177.826"
# Log, "2025-06-13 15:45:08",         main, 16.18., "Iteration # = 7"
# Log, "2025-06-13 15:45:08",         main, 16.19., "T = 176.96"
# Log, "2025-06-13 15:45:08",         main, 16.20., "Iteration # = 8"
# Log, "2025-06-13 15:45:08",         main, 16.21., "T = 176.18"
# Log, "2025-06-13 15:45:08",         main, 16.22., "Iteration # = 9"
# Log, "2025-06-13 15:45:08",         main, 16.23., "T = 175.476"
# Log, "2025-06-13 15:45:08",         main, 16.112., "Iteration # = 54"
# Log, "2025-06-13 15:45:08",         main, 16.113., "T = 169.064"
# Log, "2025-06-13 15:45:08",         main, 16.114., "Iteration # = 55"
# Log, "2025-06-13 15:45:08",         main, 16.115., "T = 169.058"
# Log, "2025-06-13 15:45:08",         main, 16.116., "Iteration # = 56"
# Log, "2025-06-13 15:45:08",         main, 16.117., "T = 169.052"
# Log, "2025-06-13 15:45:08",         main, 16.118., "Iteration # = 57"
# Log, "2025-06-13 15:45:08",         main, 16.119., "T = 169.047"
# Log, "2025-06-13 15:45:08",         main, 16.120., "Iteration # = 58"
# Log, "2025-06-13 15:45:08",         main, 16.121., "T = 169.042"
# Log, "2025-06-13 15:45:08",         main, 16.122., "Iteration # = 59"
# Log, "2025-06-13 15:45:08",         main, 16.123., "T = 169.038"
# Log, "2025-06-13 15:45:08",         main, 16.124., "Iteration # = 60"
# Log, "2025-06-13 15:45:08",         main, 16.125., "T = 169.035"
# Log, "2025-06-13 15:45:08",         main, 16.126., "Iteration # = 61"
# Log, "2025-06-13 15:45:08",         main, 16.127., "T = 169.031"
# Log, "2025-06-13 15:45:08",         main, 16.128., "Iteration # = 62"
# Log, "2025-06-13 15:45:08",         main, 16.129., "T = 169.028"
# Log, "2025-06-13 15:45:08",         main, 16.130., "Iteration # = 63"
# Log, "2025-06-13 15:45:08",         main, 16.131., "T = 169.025"
# Log, "2025-06-13 15:45:08",         main, 16.132., "Iteration # = 64"
# Log, "2025-06-13 15:45:08",         main, 16.133., "T = 169.023"
# Log, "2025-06-13 15:45:08",         main, 16.134., "Iteration # = 65"
# Log, "2025-06-13 15:45:08",         main, 16.135., "T = 169.021"
# Log, "2025-06-13 15:45:08",         main, 16.136., "Iteration # = 66"
# Log, "2025-06-13 15:45:08",         main, 16.137., "T = 169.019"
# Log, "2025-06-13 15:45:08",         main, 16.138., "Iteration # = 67"
# Log, "2025-06-13 15:45:08",         main, 16.139., "T = 169.017"
# Log, "2025-06-13 15:45:08",         main, 16.140., "Iteration # = 68"
# Log, "2025-06-13 15:45:08",         main, 16.141., "T = 169.015"
# Log, "2025-06-13 15:45:08",         main, 16.142., "Iteration # = 69"
# Log, "2025-06-13 15:45:08",         main, 16.143., "T = 169.014"
# Log, "2025-06-13 15:45:08",         main, 16.144., "Iteration # = 70"
# Log, "2025-06-13 15:45:08",         main, 16.145., "T = 169.012"
# Log, "2025-06-13 15:45:08",         main, 16.146., "Iteration # = 71"
# Log, "2025-06-13 15:45:08",         main, 16.147., "T = 169.011"
# Log, "2025-06-13 15:45:08",         main, 16.148., "Iteration # = 72"
# Log, "2025-06-13 15:45:08",         main, 16.149., "T = 169.01"
# Log, "2025-06-13 15:45:08",         main, 16.150., "run microwave radiative transfer"

# %%
## set EZ parameters

##  EZ abundances and temperature in Cheng (2020) 
xNH3=351     # deep-layer abundance, ppmv
xH2O=2500    # ppmv
T1bar=169    # 1-bar temperature, K

## use the first ap column of the block
Jindex=0   # Jindex ∈ [0, nx2-1]

## RH limit 
RHmax=1  # limit of relative humidity, 1 means 100%, only affects NH3 cloud-layer, set to 1 in EZ
maxint=200  # do not change

# %%
## ---------------    a moist adiabatic + uniform NH3  ---------------------------
adiabate="pseudo"

# build the atmosphere with a fixed top temperature (T1bar) 
mb.construct_atmosphere(pin, xNH3, T1bar, RHmax, Jindex, adiabate, xH2O, maxint)

## calc for the Jindex_st column profile
aircolumn = mb.get_aircolumn(mb.k_st, mb.j_st + Jindex, mb.i_st, mb.i_ed)   
#### loop over layers bottom up
nlyr=len(aircolumn)             ## default 1600 pressure layers

moist_temp= np.array([0.0]*nlyr)      ## temperature, K
moist_theta= np.array([0.0]*nlyr)     ## potential temperature, K, reference pressure P0 = 1 bar

for i in range(nlyr): 
    moist_temp[i] = mb.get_temp(mb.k_st, mb.j_st + Jindex,i)    
    moist_theta[i] = mb.get_theta(P0, mb.k_st, mb.j_st + Jindex,i)
# Out:
# Log, "2025-06-13 15:45:08", pycanoe_construct_atmosphere, 18., "Installing monitor pycanoe_construct_atmosphere"

# %%
## ---------------    a dry adiabatic + uniform NH3  ---------------------------
adiabate="dry"

mb.construct_atmosphere(pin, xNH3, T1bar, RHmax, Jindex, adiabate, xH2O, maxint)

## calc for the Jindex_st column profile
aircolumn = mb.get_aircolumn(mb.k_st, mb.j_st + Jindex, mb.i_st, mb.i_ed)   
#### loop over layers bottom up
nlyr=len(aircolumn)             ## default 1600 pressure layers

dry_temp= np.array([0.0]*nlyr)      ## temperature, K
dry_theta= np.array([0.0]*nlyr)     ## potential temperature, K, reference pressure P0 = 1 bar

for i in range(nlyr): 
    dry_temp[i] = mb.get_temp(mb.k_st, mb.j_st + Jindex,i)    
    dry_theta[i] = mb.get_theta(P0, mb.k_st, mb.j_st + Jindex,i)

# %%
with h5py.File("juno_mwr_fwd_case-EZ-moist-main.nc", "r") as f:
    pressure = f["press"][0,:,0,0]*1E-5

# plot the temperature and potential temperature profiles
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(moist_temp, pressure, label='Moist Adiabatic', color='blue')
plt.plot(dry_temp, pressure, 'r--', label='Dry Adiabatic')
plt.xlabel('Temperature (K)')
plt.ylabel('Pressure (bar)')

plt.yscale('log')
plt.ylim(1000,0.1)
plt.xlim(100,1500)

ax2 = plt.gca().twiny()
ax2.plot(moist_theta, pressure, label='Moist Potential Temperature', color='blue')
ax2.plot(dry_theta, pressure, 'r--', label='Dry Potential Temperature')
ax2.set_xlabel('Potential Temperature (K)')
ax2.set_xlim(100,200)


plt.legend()
plt.grid()
plt.show()

# %%
# get radance obj
rad = mb.get_rad()
nband = rad.get_num_bands()

# calculate the radiance for the Jindex_st column
rad.cal_radiance(mb, mb.k_st, mb.j_st + Jindex)
nray=len(angle)
tb =np.zeros((nband, nray))

print(f"Number of bands: {nband}, Number of angles: {nray}")

for ib in range(nband):
    toa = rad.get_band(ib).get_toa()[0]
    tb[ib, :] = toa

# plot the radiance for each band
plt.figure(figsize=(10, 6))
for ib in range(nband):
    plt.plot(angle, tb[ib, :], label=f'Band {ib+1}')
plt.xlabel('Incident Angle (degrees)')
plt.ylabel('Top of Atmosphere Brightness Temperature (K)')
plt.title('Top of Atmosphere Brightness Temperature for Each Band')
plt.legend()
plt.grid()
plt.show()
# Out:
# Number of bands: 6, Number of angles: 4
